# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
from nltk.wsd import lesk
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
sentence1 = "Keep your savings in the bank"

# %%
print(lesk(word_tokenize(sentence1), 'bank'))
# Out:
# Synset('savings_bank.n.02')

# %%
sentence2 = "It's so risky to drive over the banks of the road"

# %%
print(lesk(word_tokenize(sentence2), 'bank'))
# Out:
# Synset('bank.v.07')

# %%
from nltk.corpus import wordnet as wn
for ss in wn.synsets('won'):
  print(ss, ss.definition())
# Out:
# Synset('south_korean_won.n.01') the basic unit of money in South Korea
# Synset('north_korean_won.n.01') the basic unit of money in North Korea
# Synset('win.v.01') be the winner in a contest or competition; be victorious
# Synset('acquire.v.05') win something through one's efforts
# Synset('gain.v.05') obtain advantages, such as points, etc.
# Synset('succeed.v.01') attain success or reach a desired goal
# Synset('won.a.01') not subject to defeat
