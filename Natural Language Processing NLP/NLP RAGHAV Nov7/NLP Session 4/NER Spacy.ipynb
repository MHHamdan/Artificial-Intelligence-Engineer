# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import spacy
nlp=spacy.load("en_core_web_sm")
# Print the names of the pipeline components
print(nlp.pipe_names)
nlp.entity
# Out:
# ['tagger', 'parser', 'ner']

# %%
nlp.disable_pipes('tagger', 'parser')
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7f83e78e8320>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7f83e76726a8>)]

# %%
print(nlp.pipe_names)
# Out:
# ['tagger', 'parser', 'ner']

# %%
nlp.add_pipe
# Out:
# <bound method Language.add_pipe of <spacy.lang.en.English object at 0x7f83ea32f0f0>>

# %%
print(nlp.pipe_names)
# Out:
# ['tagger', 'parser', 'ner']

# %% [markdown]
# POS -POS tagging is the task of automatically assigning POS tags to all the words of a sentence

# %%
# Create an nlp object
doc = nlp("He went to play basketball")
 
# Iterate over the tokens
for token in doc:
    # Print the token and its part-of-speech tag
    print(token.text, "-->", token.pos_)
# Out:
# He --> PRON
# went --> VERB
# to --> PART
# play --> VERB
# basketball --> NOUN

# %%
spacy.explain("PRON")
# Out:
# 'pronoun'

# %% [markdown]
# Chunking- dependecy parsing - Every sentence has a grammatical structure to it and with the help of dependency parsing, we can extract this structure

# %%
# dependency parsing
for token in doc:
    print(token.text, "-->", token.dep_)
# Out:
# He --> nsubj
# went --> ROOT
# to --> aux
# play --> advcl
# basketball --> dobj

# %% [markdown]
# dependency tag ROOT denotes the main verb or action in the sentence. The other words are directly or indirectly connected to the ROOT word of the sentence

# %%
spacy.explain("nsubj"), spacy.explain("ROOT"), spacy.explain("aux"), spacy.explain("advcl"), spacy.explain("dobj")
# Out:
# ('nominal subject',
#  None,
#  'auxiliary',
#  'adverbial clause modifier',
#  'direct object')

# %% [markdown]
# Named Entity Recognition- Entities are the words or groups of words that represent information about common things such as persons, locations, organizations, etc. These entities have proper names

# %%
doc=nlp("Berlin is the capital of Germany;and the residence of Chancellor Angela Merkel")
doc.ents
# Out:
# (Berlin, Germany;and, Angela Merkel)

# %%
print(doc.ents[0], doc.ents[0].label_)
# Out:
# Berlin GPE

# %%
text="On Tuesday , Apple announced its plans for another major chunk of the money:It will buy back a further $75 billion in stock."
doc=nlp(text)
for ent in doc.ents :
  print(ent.text,"\t",ent.label_)
# Out:
# Tuesday 	 DATE
# Apple 	 ORG
# $75 billion 	 MONEY

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
text="Joe Biden will meet CEO of Google Mr.Sundar Pichai in California on next Tuesday"
doc=nlp(text)
for ent in doc.ents :
  print(ent.text,"\t",ent.label_)
# Out:
# Joe Biden 	 PERSON
# Google Mr 	 ORG
# Sundar Pichai 	 PERSON
# California 	 GPE
# next Tuesday 	 DATE

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
spacy.explain("PERSON")
# Out:
# 'People, including fictional'

# %% [markdown]
# Why Spacy is used for NER
#
# Easy pipeline creation
# Different entity types compared to nltk
# Informal language corpora
# Easily find entities in Tweets and chat messages
# Quickly growing!
