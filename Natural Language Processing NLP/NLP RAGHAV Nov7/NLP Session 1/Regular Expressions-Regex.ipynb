# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

# %%
sentence=' Ram has 10 catz,Shyam has 20 DOGS'
sentence
# Out:
# ' Ram has 10 catz,Shyam has 20 DOGS'

# %%
pat1= r"[a-z]"

# %%
print(re.search(pat1,sentence))
# Out:
# <_sre.SRE_Match object; span=(2, 3), match='a'>

# %%
print(re.findall(pat1,sentence))
# Out:
# ['a', 'm', 'h', 'a', 's', 'c', 'a', 't', 'z', 'h', 'y', 'a', 'm', 'h', 'a', 's']

# %%
pat5=r'[A-Z]'

# %%
print(re.findall(pat5,sentence))
# Out:
# ['R', 'S', 'D', 'O', 'G', 'S']

# %%
pat2=r"[0-9]"

# %%
print(re.findall(pat2,sentence))
# Out:
# ['1', '0', '2', '0']

# %%
pat4=r'[\d+]'
print(re.findall(pat4,s))
# Out:
# ['1', '0', '2', '0']

# %%
pat3=r"[A-Z|0-9]"

# %%
print(re.findall(pat3,sentence))
# Out:
# ['R', '1', '0', 'S', '2', '0', 'D', 'O', 'G', 'S']
